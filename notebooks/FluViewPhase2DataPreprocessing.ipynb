# %%
import pandas as pd

# %%
ILINet_df = pd.read_csv('../data/FluViewPhase2Data/ILINet.csv')
WHO_NREVSS_Clinical_Labs_df = pd.read_csv('../data/FluViewPhase2Data/WHO_NREVSS_Clinical_Labs.csv',skiprows=[0])
WHO_NREVSS_Combined_prior_to_2015_16_df = pd.read_csv('../data/FluViewPhase2Data/WHO_NREVSS_Combined_prior_to_2015_16.csv',skiprows=[0])
WHO_NREVSS_Public_Health_Labs_df = pd.read_csv("../data/FluViewPhase2Data/WHO_NREVSS_Public_Health_Labs.csv",skiprows=[0])
cdc_truth = pd.read_csv("../data/CDC/truth-Incident Hospitalizations.csv")

# %%
ILINet_df[ILINet_df['YEAR'] == 2023]
# Out:
#       REGION TYPE                                        REGION  YEAR  WEEK  \
# 34468      States                                       Alabama  2023     1
# 34469      States                                        Alaska  2023     1
# 34470      States                                       Arizona  2023     1
# 34471      States                                      Arkansas  2023     1
# 34472      States                                    California  2023     1
# ...           ...                                           ...   ...   ...
# 34738      States                                       Wyoming  2023     5
# 34739      States  Commonwealth of the Northern Mariana Islands  2023     5
# 34740      States                                   Puerto Rico  2023     5
# 34741      States                                Virgin Islands  2023     5
# 34742      States                                 New York City  2023     5
#
# ...

# %%
WHO_NREVSS_Clinical_Labs_df[WHO_NREVSS_Clinical_Labs_df['YEAR'] == 2023]
# Out:
#       REGION TYPE          REGION  YEAR  WEEK TOTAL SPECIMENS TOTAL A TOTAL B  \
# 20412      States         Alabama  2023     1             418      15       0
# 20413      States          Alaska  2023     1               X       X       X
# 20414      States         Arizona  2023     1             449      32       0
# 20415      States        Arkansas  2023     1             478      21       2
# 20416      States      California  2023     1           16489    1151       7
# ...           ...             ...   ...   ...             ...     ...     ...
# 20677      States       Wisconsin  2023     5            9428     195       7
# 20678      States         Wyoming  2023     5               X       X       X
# 20679      States     Puerto Rico  2023     5               0       0       0
# 20680      States  Virgin Islands  2023     5               X       X       X
# 20681      States   New York City  2023     5               X       X       X
#
# ...

# %%
cdc_truth[cdc_truth['date'] == '2023-01-07']
# Out:
#             date location         location_name  value
# 8012  2023-01-07       02                Alaska     32
# 8013  2023-01-07       01               Alabama    124
# 8014  2023-01-07       05              Arkansas    146
# 8015  2023-01-07       04               Arizona    347
# 8016  2023-01-07       06            California    854
# 8017  2023-01-07       08              Colorado    146
# 8018  2023-01-07       09           Connecticut    160
# 8019  2023-01-07       11  District of Columbia     15
# 8020  2023-01-07       10              Delaware     41
# 8021  2023-01-07       12               Florida   1085
# 8022  2023-01-07       13               Georgia    159
# 8023  2023-01-07       15                Hawaii     10
# 8024  2023-01-07       19                  Iowa    202
# 8025  2023-01-07       16                 Idaho    101
# 8026  2023-01-07       17              Illinois    383
# 8027  2023-01-07       18               Indiana    342
# ...
